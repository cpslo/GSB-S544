# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c089b62b-af40-410b-adfb-9cf83dda4d97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c089b62b-af40-410b-adfb-9cf83dda4d97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: create a dataframe for the ameshousing.csv

import io

df = pd.read_csv(io.BytesIO(uploaded['ameshousing.csv']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-b45d2d64beb5> in <cell line: 5>()
#       3 import io
#       4
# ----> 5 df = pd.read_csv(io.BytesIO(uploaded['ameshousing.csv']))
#
# KeyError: 'ameshousing.csv'

# %%
import io
import pandas as pd

# Get the actual filename from the uploaded dictionary
# Assuming there's only one file uploaded
filename = list(uploaded.keys())[0]

# Now use the correct filename to read the CSV
df = pd.read_csv(io.BytesIO(uploaded[filename]))

# %%
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
lr = LinearRegression()


df = pd.read_csv(io.BytesIO(uploaded['ameshousing.csv']))
X = ames[["Gr Liv Area", "TotRms AbvGrd"]]
y = ames["SalePrice"]



X_train, X_test, y_train, y_test = train_test_split(X, y)

X_train_s = (X_train - X_train.mean())/X_train.std()

lr_fitted = lr.fit(X_train_s, y_train)
lr_fitted.coef_
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-9411628d31a0> in <cell line: 4>()
#       2
#       3
# ----> 4 df = pd.read_csv(io.BytesIO(uploaded['ameshousing.csv']))
#       5 X = ames[["Gr Liv Area", "TotRms AbvGrd"]]
#       6 y = ames["SalePrice"]
#
# KeyError: 'ameshousing.csv'
